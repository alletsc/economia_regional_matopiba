# %%
import geopandas as gpd

# %%
matopiba_estados = gpd.read_file(
    'S:\gits_stella\Python\MATOPIBA_economia_regional\Matopiba\datasets\estados\Matopiba_Estados.shp')
matopiba_estados.plot()
# Out:
# <AxesSubplot:>

# %%
microreg = gpd.read_file(
    "S:\gits_stella\Python\MATOPIBA_economia_regional\Matopiba\datasets\microregioes\Matopiba_Microrregioes.shp")
microreg.plot()
# Out:
# <AxesSubplot:>

# %%
perimetro = gpd.read_file(
    "S:\gits_stella\Python\MATOPIBA_economia_regional\Matopiba\datasets\perimetro\Matopiba_Perimetro.shp")
perimetro.plot()
# Out:
# <AxesSubplot:>
